# %%
import fastai; fastai.__version__
from fastai.vision import *

# %%
import sys; sys.path.append("../dev")
from local.script import run_command

# %%
EXPORT_PATH = Path("./experiment_exports/");EXPORT_PATH.ls()
# Out:
# [PosixPath('experiment_exports/experiment1')]

# %%
i = 1
EXP_PATH = (EXPORT_PATH/f"experiment{i}"); EXP_PATH.ls()
# Out:
# [PosixPath('experiment_exports/experiment1/training_log.csv'),
#  PosixPath('experiment_exports/experiment1/stderr.log'),
#  PosixPath('experiment_exports/experiment1/tmp'),
#  PosixPath('experiment_exports/experiment1/models')]

# %%
pd.read_csv(EXPORT_PATH/f"experiment{i}/training_log.csv")
# Out:
#     epoch  train_loss  valid_loss      dice   time
# 0       0         NaN         NaN  0.786181  14:00
# 1   epoch  train_loss  valid_loss      dice   time
# 2       0         NaN         NaN  0.786181  14:00
# 3   epoch  train_loss  valid_loss      dice   time
# 4       0         NaN         NaN  0.786181  14:00
# 5   epoch  train_loss  valid_loss      dice   time
# 6       0         NaN         NaN  0.786181  14:00
# 7   epoch  train_loss  valid_loss      dice   time
# 8       0         NaN         NaN  0.786181  14:00
# 9   epoch  train_loss  valid_loss      dice   time
# 10      0         NaN         NaN  0.786181  14:00
# 11  epoch  train_loss  valid_loss      dice   time
# 12      0         NaN         NaN  0.786181  14:01
# 13  epoch  train_loss  valid_loss      dice   time
# 14      0         NaN         NaN  0.786181  14:21
# 15  epoch  train_loss  valid_loss      dice   time
# 16      0         NaN         NaN  0.786181  14:21
# 17  epoch  train_loss  valid_loss      dice   time
# 18      0         NaN         NaN  0.786181  14:21
# 19  epoch  train_loss  valid_loss      dice   time
# 20      0         NaN         NaN  0.786181  14:21
# 21  epoch  train_loss  valid_loss      dice   time
# 22      0         NaN         NaN  0.786181  14:21
# 23  epoch  train_loss  valid_loss      dice   time
# 24      0         NaN         NaN  0.786181  14:21
# 25  epoch  train_loss  valid_loss      dice   time
# 26      0         NaN         NaN  0.786181  14:21
# 27  epoch  train_loss  valid_loss      dice   time
# 28      0         NaN         NaN  0.786181  13:50
# 29  epoch  train_loss  valid_loss      dice   time
# 30      0         NaN         NaN  0.786181  13:50
# 31  epoch  train_loss  valid_loss      dice   time
# 32      0         NaN         NaN  0.786181  13:50
# 33  epoch  train_loss  valid_loss      dice   time
# 34      0         NaN         NaN  0.786181  13:50
# 35  epoch  train_loss  valid_loss      dice   time
# 36      0         NaN         NaN  0.786181  13:50
# 37  epoch  train_loss  valid_loss      dice   time
# 38      0         NaN         NaN  0.786181  13:50
# 39  epoch  train_loss  valid_loss      dice   time
# 40      0         NaN         NaN  0.786181  13:50

# %%
print(open(EXPORT_PATH/f"experiment{i}/stderr.log").read())
# Out:
# APPENDED NEW LOG at: 09/15/2019, 22:27:16
# COMMAND: ['python', '/home/turgutluk/fastai/fastai/launch.py', '--gpus=0123457', '/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py', '--PATH=/home/turgutluk/data/siim_acr_pneu', '--IMAGES=train/images_1024', '--MASKS=train/masks_1024', '--CODES=codes.txt', '--TRAIN=train.txt', '--VALID=0.1', '--TEST=test.txt', '--bs=1', '--size=1024', '--imagenet_pretrained=1', '--max_lr=3e-3', '--model_name=bestmodel', '--epochs=1', '--tracking_metric=dice', '--void_name=Void', '--loss_function=xentropy', '--opt=radam', '--EXPORT_PATH=./experiment_exports/experiment1']
# STDERR: Traceback (most recent call last):
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 37, in <module>
#     gpu:Param("GPU to run on, can handle multi gpu", str)=None):
#   File "/home/turgutluk/fastai/fastai/script.py", line 40, in call_parse
#     func(**args.__dict__)
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 132, in main
#     preds, targs = learn.get_preds(getattr(DatasetType, dtype))
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 339, in get_preds
#     activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 44, in get_preds
#     zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 59, in validate
#     val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 26, in loss_batch
#     out = model(*xb)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 338, in forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: CUDA out of memory. Tried to allocate 424.00 MiB (GPU 0; 10.73 GiB total capacity; 6.42 GiB already allocated; 158.19 MiB free; 1.13 GiB cached)
# Traceback (most recent call last):
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 37, in <module>
#     gpu:Param("GPU to run on, can handle multi gpu", str)=None):
#   File "/home/turgutluk/fastai/fastai/script.py", line 40, in call_parse
#     func(**args.__dict__)
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 132, in main
#     preds, targs = learn.get_preds(getattr(DatasetType, dtype))
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 339, in get_preds
#     activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 44, in get_preds
#     zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 59, in validate
#     val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 26, in loss_batch
#     out = model(*xb)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 338, in forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: CUDA out of memory. Tried to allocate 424.00 MiB (GPU 2; 10.73 GiB total capacity; 8.38 GiB already allocated; 357.56 MiB free; 1.23 GiB cached)
# Traceback (most recent call last):
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 37, in <module>
#     gpu:Param("GPU to run on, can handle multi gpu", str)=None):
#   File "/home/turgutluk/fastai/fastai/script.py", line 40, in call_parse
#     func(**args.__dict__)
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 132, in main
#     preds, targs = learn.get_preds(getattr(DatasetType, dtype))
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 339, in get_preds
#     activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 44, in get_preds
#     zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 59, in validate
#     val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 26, in loss_batch
#     out = model(*xb)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 338, in forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: CUDA out of memory. Tried to allocate 424.00 MiB (GPU 5; 10.73 GiB total capacity; 8.37 GiB already allocated; 347.56 MiB free; 1.24 GiB cached)
# Traceback (most recent call last):
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 37, in <module>
#     gpu:Param("GPU to run on, can handle multi gpu", str)=None):
#   File "/home/turgutluk/fastai/fastai/script.py", line 40, in call_parse
#     func(**args.__dict__)
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 132, in main
#     preds, targs = learn.get_preds(getattr(DatasetType, dtype))
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 339, in get_preds
#     activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 44, in get_preds
#     zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 59, in validate
#     val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 26, in loss_batch
#     out = model(*xb)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 338, in forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: CUDA out of memory. Tried to allocate 424.00 MiB (GPU 7; 10.73 GiB total capacity; 8.39 GiB already allocated; 333.56 MiB free; 1.23 GiB cached)
# Traceback (most recent call last):
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 37, in <module>
#     gpu:Param("GPU to run on, can handle multi gpu", str)=None):
#   File "/home/turgutluk/fastai/fastai/script.py", line 40, in call_parse
#     func(**args.__dict__)
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 132, in main
#     preds, targs = learn.get_preds(getattr(DatasetType, dtype))
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 339, in get_preds
#     activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 44, in get_preds
#     zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 59, in validate
#     val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 26, in loss_batch
#     out = model(*xb)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 338, in forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: CUDA out of memory. Tried to allocate 424.00 MiB (GPU 3; 10.73 GiB total capacity; 8.37 GiB already allocated; 339.56 MiB free; 1.25 GiB cached)
# Traceback (most recent call last):
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 37, in <module>
#     gpu:Param("GPU to run on, can handle multi gpu", str)=None):
#   File "/home/turgutluk/fastai/fastai/script.py", line 40, in call_parse
#     func(**args.__dict__)
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 132, in main
#     preds, targs = learn.get_preds(getattr(DatasetType, dtype))
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 339, in get_preds
#     activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 44, in get_preds
#     zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 59, in validate
#     val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 26, in loss_batch
#     out = model(*xb)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 338, in forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: CUDA out of memory. Tried to allocate 424.00 MiB (GPU 4; 10.73 GiB total capacity; 8.40 GiB already allocated; 343.56 MiB free; 1.21 GiB cached)
# Traceback (most recent call last):
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 37, in <module>
#     gpu:Param("GPU to run on, can handle multi gpu", str)=None):
#   File "/home/turgutluk/fastai/fastai/script.py", line 40, in call_parse
#     func(**args.__dict__)
#   File "/home/turgutluk/git/fast-kaggle/dev/segmentation_training.py", line 132, in main
#     preds, targs = learn.get_preds(getattr(DatasetType, dtype))
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 339, in get_preds
#     activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 44, in get_preds
#     zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 59, in validate
#     val_loss = loss_batch(model, xb, yb, loss_func, cb_handler=cb_handler)
#   File "/home/turgutluk/fastai/fastai/basic_train.py", line 26, in loss_batch
#     out = model(*xb)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/fastai/fastai/layers.py", line 136, in forward
#     nres = l(res)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/container.py", line 92, in forward
#     input = module(input)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/module.py", line 493, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/home/turgutluk/.conda/envs/my_fastai/lib/python3.7/site-packages/torch/nn/modules/conv.py", line 338, in forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: CUDA out of memory. Tried to allocate 424.00 MiB (GPU 1; 10.73 GiB total capacity; 8.38 GiB already allocated; 347.56 MiB free; 1.23 GiB cached)
# STDOUT:
